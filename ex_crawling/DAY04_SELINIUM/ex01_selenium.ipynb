# %% [markdown]
# ### 【 동적 웹 페이지 크롤링 】
# - Selenium 패키지
#     * 웹 페이지 실행 후 사용자 이벤트 진행, JS 실행 결과 내용 추출 패키지 중 하나
#     * 설치 : conda install selenium
#     * 설정
#         - 브라우저 기능 수행을 위한 브라우저 드라이버 설치 필요
#         - Selenium 버전 4.6이상부터는 자동 처리 됨

# %%
## 모듈 로딩 
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

import selenium 

print(f'selenium v.{selenium.__version__}')
# Out:
# selenium v.4.38.0

# %% [markdown]
# [1] 코드기반 구글 브라우저 및 웹 페이지 띄우기 <hr>

# %%
## =========================================================
## Selenium 4.6 이전 드라이버 드라이버 설정 
## =========================================================
chrome_path = "../chrome-win64/chrome.exe"
driver_path = "../chromedriver-win64/chromedriver.exe"

## - 웹드라이버 설정 
options = Options()
options.binary_location = chrome_path

## - 웹드라이버 서비스 설정, 크롬 브라우저 실행
service = Service(driver_path)
driver = webdriver.Chrome(service=service, options=options)

## - 특정 웹 페이지 띄우기 
driver.get("https://google.com")
print(driver.title)
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[2], line 13
#      11 ## - 웹드라이버 서비스 설정, 크롬 브라우저 실행
#      12 service = Service(driver_path)
# ---> 13 driver = webdriver.Chrome(service=service, options=options)
#      15 ## - 특정 웹 페이지 띄우기
#      16 driver.get("https://google.com")
#
# File c:\Users\kdt008\anaconda3\envs\DATA_311\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:47, in WebDriver.__init__(self, options, service, keep_alive)
#      44 service = service if service else Service()
#      45 options = options if options else Options()
# ---> 47 super().__init__(
#      48     browser_name=DesiredCapabilities.CHROME["browserName"],
#      49     vendor_prefix="goog",
#      50     options=options,
#      51     service=service,
#      52     keep_alive=keep_alive,
#      53 )
#
# File c:\Users\kdt008\anaconda3\envs\DATA_311\Lib\site-packages\selenium\webdriver\chromium\webdriver.py:71, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      62 executor = ChromiumRemoteConnection(
#      63     remote_server_addr=self.service.service_url,
#      64     browser_name=browser_name,
#    (...)     67     ignore_proxy=options._ignore_local_proxy,
#      68 )
#      70 try:
# ---> 71     super().__init__(command_executor=executor, options=options)
#      72 except Exception:
#      73     self.quit()
#
# File c:\Users\kdt008\anaconda3\envs\DATA_311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:263, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options, locator_converter, web_element_cls, client_config)
#     261 self._authenticator_id = None
#     262 self.start_client()
# --> 263 self.start_session(capabilities)
#     264 self._fedcm = FedCM(self)
#     266 self._websocket_connection = None
#
# File c:\Users\kdt008\anaconda3\envs\DATA_311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:366, in WebDriver.start_session(self, capabilities)
#     364 caps = _create_caps(capabilities)
#     365 try:
# --> 366     response = self.execute(Command.NEW_SESSION, caps)["value"]
#     367     self.session_id = response.get("sessionId")
#     368     self.caps = response.get("capabilities")
#
# File c:\Users\kdt008\anaconda3\envs\DATA_311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File c:\Users\kdt008\anaconda3\envs\DATA_311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:233, in ErrorHandler.check_response(self, response)
#     231         alert_text = value["alert"].get("text")
#     232     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 233 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created
# from unknown error: no chrome binary at ../chrome-win64/chrome.exe; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#sessionnotcreatedexception
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff736547a35
# 	0x7ff736547a90
# 	0x7ff7362c16ad
# 	0x7ff7362fdfb0
# 	0x7ff7362fbbd9
# 	0x7ff736350a42
# 	0x7ff736350280
# 	0x7ff73630b068
# 	0x7ff73630be93
# 	0x7ff7368029d0
# 	0x7ff7367fce50
# 	0x7ff73681cc45
# 	0x7ff7365630ce
# 	0x7ff73656adbf
# 	0x7ff736550c14
# 	0x7ff736550dcf
# 	0x7ff736536828
# 	0x7ffbd19ee8d7
# 	0x7ffbd292c53c

# %%
## =========================================================
## Selenium 4.6 이상 드라이버 자동 설치/관리 (Selenium Manager)
## =========================================================
## - 크롬 브라우저 실행
driver = webdriver.Chrome()    

## - 페이지 열기   
driver.get("https://www.naver.com")

## - 페이지 제목 출력
print(driver.title)                  
# driver.quit()  # 작업 끝나면 창 닫기
# Out:
# NAVER

# %% [markdown]
# [2] 창이 보지 않는 Headless 모드 <hr>

# %%
## 모듈 로딩
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

## 브라우저 설정 
options = Options()
options.add_argument("--headless=new")  ## - 창 띄우지 않고 백그라운드 실행

## 웹 브라우저 로딩 및 지정된 웹 페이지 열기 
driver = webdriver.Chrome(options=options)
driver.get("https://www.naver.com")
print(driver.title)

## 웹 브라우저 종료
driver.quit()
# Out:
# NAVER

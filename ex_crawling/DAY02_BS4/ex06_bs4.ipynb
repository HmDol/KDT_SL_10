# %% [markdown]
# ### [ 웹 스크래핑 - 정보추출 ]
# - 수집된 웹 데이터에서 필요한 정보 추출하는 작업 : 스크래핑
# - 스크래핑을 편리하게 진행하기 위한 패키지 : BeautifulSoup4
# - binary/str 타입의 웹 데이터 ==> 객체화 (DOM)해서 프로그램 쉽게 사용할 수 있도록 함

# %% [markdown]
# [1] 모듈 로딩 <hr>

# %%
from bs4 import BeautifulSoup           ## 웹데이터 객체화 및 정보 추출용 모듈

# %% [markdown]
# [2] markup 문자열에서 정보 추출<hr>
# - select_one() 메서드
#     - 조건에 맞는 첫번째 tag반환
#     - find()메서드와 검색 결과 동일
#
# - select() 메서드
#     - 조건에 맞는 모든 tag list로 반환
#     - find_all() 메서드와 검색 결과 동일
#
# - css 선택자
#     - tag의 id 속성 : #id명
#     - tag의 class 속성 : .class명
#     - 자식 태그 : 부모태그 > 자식태그
#     - 자손 태그 : 상위/부모태그 &nbsp;&nbsp; 하위/자속태그

# %% [markdown]
# [ 실습 ] fruits-vegetables.html 파일에서 css selector 로 추출 <hr>

# %%
## [ 실습 ] fruis-vegetables.html 파일에서 css selector 로 추출

html_file = '../Data/chap02.html'
with open (html_file, encoding='utf-8') as f:
    bs = BeautifulSoup(f.read(), 'html.parser')

# %%
## 1. id가 footer인 h1태그 추출
bs.select_one('#footer')

# %%
## 3. 부모tag>자식tag로 a 태그 추출
bs.select_one('#link>.external_link')
bs.select_one('#link>.external_link2')
bs.select_one('#link>.external_link.external_link2')

# %%
## [4] 상위/조상 tag        하위/자손tag 추출
bs.select_one('div#class1 #second')

# %%
## [5]부모/자식, 조상/자손 관계 x. 여러개 추출
bs.select('#link, #footer')
# Out:
# []

# %% [markdown]
# [3] Naver 페이지에서 데이터 추출<hr>

# %%
##  1) 웹 페이지 가져오기
from urllib.request import urlopen
n_url = 'http://www.naver.com'

htmlbs = BeautifulSoup(n_url, 'html.parser')

htmlbs.select_one('#topPayArea > a > span')
htmlbs.string
# Out:
# C:\Users\kdt008\AppData\Local\Temp\ipykernel_27372\2136430199.py:5: MarkupResemblesLocatorWarning: The input passed in on this line looks more like a URL than HTML or XML.
#
# If you meant to use Beautiful Soup to parse the web page found at a certain URL, then something has gone wrong. You should use an Python package like 'requests' to fetch the content behind the URL. Once you have the content as a string, you can feed that string into Beautiful Soup.
#
# However, if you want to parse some data that happens to look like a URL, then nothing has gone wrong: you are using Beautiful Soup correctly, and this warning is spurious and can be filtered. To make this warning go away, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import MarkupResemblesLocatorWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)
#
#   htmlbs = BeautifulSoup(n_url, 'html.parser')
# 'http://www.naver.com'

# %%
## 가상환경 체크
import pandas 
import cv2
import matplotlib
import sklearn

# %%
print(pandas.__version__)
print(cv2.__version__)
print(matplotlib.__version__)
print(sklearn.__version__)
# Out:
# 2.3.3
# 4.12.0
# 3.10.8
# 1.8.0

# %% [markdown]
# ##### [Numpy - 범위내 데이터 활용 ndarray 생성]
# - numpy.random.rand() / randn() : -1 ~ 1 사이의 난수 / 평균 0 분산 1인 난수들
# - numpy.arage() : range() 함수와 동일
# - numpy.linspace() : 시작값 ~ 끝값 n 등분하기
# - numpy.logspace() : 시작값 ~ 끝값 n 등분하기 (로그 스케일)

# %%
## 모듈로딩
import numpy as np  ## 이미지 데이터 저장 관련 모듈
import cv2          ## opencv 패키지

# %%
## ============================================
## Image == > ndarray 데이터
## ============================================
img_file = '../Data/Image/blackpink.jpg'

## 이미지 데이터 로딩 : cv2.imread()
imgNP = cv2.imread(img_file)

## 이미지 로우 데이터 정보 출력
print(f'이미지 로우 데이터 정보 => {imgNP.shape}, {imgNP.ndim}차원')
# Out:
# 이미지 로우 데이터 정보 => (704, 1199, 3), 3차원

# %% [markdown]
# - 이미지와 동일 형태/타입의 ndarray 객체 생성 <hr>

# %%
img = cv2.imread('../Data/Image/girl.jpg')
img

a = np.astype(dtype='int16')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 img = cv2.imread('../Data/Image/girl.jpg')
#       2 img
# ----> 4 a = np.astype(dtype='int16')
#
# TypeError: astype() got some positional-only arguments passed as keyword arguments: 'dtype'

# %%
a = np.uint8(a)

print('변경 후', a, a.dtype())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 a = np.uint8(a)
#       3 print('변경 후', a, a.dtype())
#
# NameError: name 'a' is not defined

# %% [markdown]
# ##### 【기본 개념 이해 중심】<hr>

# %% [markdown]
# 1. X ~ B(n, p) 기대값은? 답:1
# ***① np***
# ② n/p
# ③ n(1−p)
# ④ p(1−p)

# %% [markdown]
# 2. 정규분포의 대표적인 특징은? 답:2
# ① 왼쪽으로만 치우친 분포
# ***② 평균 = 중앙값 = 최빈값***
# ③ 오른쪽 꼬리가 더 긴 분포
# ④ 이산형이다.

# %% [markdown]
# 3. 표준정규분포의 평균과 표준편차는? 답:1
# ***① (0, 1)***
# ② (1, 0)
# ③ (1, 1)
# ④ (0, 0)

# %% [markdown]
# 4. 모집단 평균 추정을 하는 경우, 신뢰구간이 넓어진다는 것은? 답:1
# **① 표본이 증가해서 불확실성이 줄었다.**
# ② 표본이 작거나 신뢰수준이 높다.
# ③ 모집단이 정규분포가 아니다.
# ④ 표본분산이 0이다.

# %% [markdown]
# 5. p-value가 매우 작으면 의미하는 것은? 답: 3
# ① 귀무가설을 기각하기 어렵다.
# ② 귀무가설을 지지한다.
# ***③ 귀무가설이 사실일 가능성이 낮다.***
# ④ 표본이 항상 정규분포를 따른다.

# %% [markdown]
# 6. 정규분포가 왜 통계학에서 중요한지 중심극한정리 관점에서 설명하시오.
# <b>특정 모집단이 정규분포가 아니더라도 표본을 충분히 크게 반복 추출하면 정규분포에 근접하게 된다.<br>
# 따라서, 현실의 많은 추론을 정규분포의 형태로 만들 수 있다. </b>

# %% [markdown]
# 7. 표본과 모집단의 차이를 간단히 설명하시오.
# <b>모집단 : 대상 집합 전체 / 표본 : 모집단의 일부분을 추출 <br>
# 모집단 전체를 검사하는 것은 현실적으로 불가능 하니, 모집단의 부분집합을 뽑아 검사함 <br/>
# 표본은 모집단의 부분 집합임 <br/></b>

# %% [markdown]
# 8. 95% 신뢰구간의 의미를 설명하시오.
# ***해당 구간의 95%가 모수의 값을 포함한다.***

# %% [markdown]
# 9. t-분포가 정규분포보다 꼬리가 두꺼운 이유는? 답: 1
# ***① 소표본에서는 불확실성이 커서***
# ② 표본이 무한히 크기 때문에
# ③ 이산형 분포여서
# ④ 평균이 0이 아니어서

# %% [markdown]
# 11. 카이제곱분포의 대표적인 사용 용도는?    답:2
# ① 평균 비교
# ***② 독립성 검정***
# ③ 비율 검정
# ④ 표준편차 비교

# %% [markdown]
# 12. 1종 오류(Type I error)의 의미는?    답:1
# ***① 참인 귀무가설을 기각***
# ② 거짓인 귀무가설을 기각
# ③ 참인 대립가설을 기각
# ④ 표본 오차가 0인 경우

# %% [markdown]
# 13. 신뢰수준을 높이면 신뢰구간은 어떻게 되는가? 답: 3
# ① 더 좁아진다.
# ② 변하지 않는다.
# ***③ 더 넓어진다.***
# ④ 무의미해진다.

# %% [markdown]
# 14. 중심극한정리(CLT)가 추론통계의 기반인 이유를 설명하시오.
# ***CLT 덕분에 표본평균이 정규성을 가지므로, 정규분포를 기반으로 한 추론이 가능해진다.***

# %% [markdown]
# 15. X ~ N(μ, σ²)를 Z로 표준화하는 공식은? 답: 3
# ① Z = X − μ
# ② Z = (X − μ)σ
# ***③ Z = (X − μ)/σ***
# ④ Z = μ − X / σ

# %% [markdown]
# 16. 정규분포에서 약 68%는 평균에서 몇 표준편차 이내에 있는가?답: 1
# ***① ±1σ***
# ② ±2σ
# ③ ±3σ
# ④ ±0.5σ

# %% [markdown]
# 17. 어떤 정규분포의 확률밀도함수(f(x))는 높고 좁으며 뾰족하다. 이때 분산 σ²는? 답: 1
# ***① 매우 크다.***
# ② 매우 작다.
# ③ 항상 1이다.
# ④ 알 수 없다.

# %% [markdown]
# 18. X ~ N(μ, σ²)에서 꼬리(tail) 확률이 더 중요한 분석은? 답: 2
# ① 중간값 분석
# **② 이상치 판정**
# ③ 산술평균 계산
# ④ 히스토그램 계산

# %% [markdown]
# 19. 어떤 문제를 맞출 확률이 일정한 상황에서,
# 학생이 8문제를 찍어서 풀었고 그중 3문제가 맞았다.
# 이때 한 문제를 맞출 성공확률 p의 추정값을 구하시오.
# ***답 : 3/8 => 0.375***

# %% [markdown]
# 20. 한 카페에 손님이 평균적으로 1분당 2명 방문한다고 한다.
#     이 카페에 1분 동안 손님이 0명 방문할 확률을 푸아송분포로 구하시오.
# 단.from scipy.stats import poisson

# %%
from scipy.stats import poisson

result = poisson.pmf(0, 2)
print(result)
# Out:
# 0.1353352832366127
